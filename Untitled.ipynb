# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
# Out:
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.DataFrame(data = {
    "area":[2600,3000,3200,3600,4000],
    "price":[550000,565000,610000,680000,725000]
#     "Time":n["1-2019"]
    
})
# df.head()
print(np.datetime_as_string(1-1011))
# Out:
# ---------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-38-f73d5c9de6f0> in <module>
#       6 })
#       7 # df.head()
# ----> 8 print(np.datetime_as_string(1-1011))
#
# <__array_function__ internals> in datetime_as_string(*args, **kwargs)
#
# TypeError: input must have type NumPy datetime

# %%
# reg.predict([[3300]])
l=[]
err=[]
for i in range(5):
    x=reg.predict([[df.iloc[i][0]]])
    l.append(x[0])
    err.append(df.iloc[i][1]-x[0])
l
# Out:
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# ...

# %%
sns.lineplot(x=df['area'],y=l,label="PREDICTED LINE")
sns.lineplot(x=df['area'],y=df['price'],linewidth=5,label="Actual Line")
plt.scatter(df.area,y=l,color="black",linewidth=5)
plt.scatter(df.area,df.price,color="red",)

# %%
sns.lineplot(x=df['area'],y=err)
plt.scatter(df.area,y=err,color="black")

# %%
# %matplotlib inline
sns.lineplot(x=df['area'],y=df['price'])
plt.scatter(df.area,df.price,color="black")

# %%
reg =linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
df.iloc[3][0]
# Out:
# 3600

# %%
# reg.predict([[3300]])
l=[]
err=[]
for i in range(5):
    x=reg.predict([[df.iloc[i][0]]])
    l.append(x[0])
    err.append(df.iloc[i][1]-x[0])
l
# Out:
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\Danish\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# ...
